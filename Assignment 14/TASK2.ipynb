# %% [raw]
# /* styles.css - Task 2 -------------------------------------------------- */
# /* Basic reset */
# * { box-sizing: border-box; margin: 0; padding: 0; }
#
# /* Page base */
# :root {
#   --max-width: 980px;
#   --accent: #2b6ef6;     /* main blue */
#   --accent-dark: #1748b8;
#   --muted: #f1f5fb;      /* hero / nav bg */
#   --card-bg: #ffffff;
#   --footer-bg: #f3f5f9;
#   --text: #1f2937;
#   --radius: 10px;
#   --gap: 16px;
# }
# body {
#   font-family: system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#   color: var(--text);
#   background: #f7f9fc;
#   line-height: 1.45;
# }
#
# /* Central wrapper to keep content width consistent */
# .wrap {
#   max-width: var(--max-width);
#   margin: 0 auto;
#   padding: 0 16px;
# }
#
# /* Header */
# .site-header {
#   background: linear-gradient(90deg, var(--accent), var(--accent-dark));
#   color: #fff;
#   padding: 20px 0;
#   box-shadow: 0 2px 6px rgba(43,110,246,0.08);
# }
# .site-header .wrap {
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   gap: var(--gap);
# }
# .brand { font-size: 1.4rem; font-weight: 700; }
#
# /* Navigation */
# .site-nav ul {
#   list-style: none;
#   display: flex;
#   gap: 12px;
#   align-items: center;
#   margin: 0;
#   padding: 0;
# }
# .site-nav a {
#   color: white;
#   text-decoration: none;
#   padding: 8px 12px;
#   border-radius: 8px;
#   font-weight: 600;
#   background: rgba(255,255,255,0.06);
# }
# .site-nav a:hover,
# .site-nav a:focus {
#   background: rgba(255,255,255,0.12);
#   outline: none;
# }
#
# /* Hamburger (hidden on wide screens) */
# .hamburger {
#   display: none;
#   background: transparent;
#   border: none;
#   color: white;
#   font-size: 1.35rem;
#   cursor: pointer;
# }
#
# /* Main content areas */
# .main-content { margin: 28px 0; }
# .hero {
#   background: var(--muted);
#   padding: 32px;
#   border-radius: var(--radius);
#   text-align: center;
#   margin-bottom: 20px;
#   box-shadow: 0 2px 8px rgba(31,41,55,0.03);
# }
# .hero h2 { font-size: 1.6rem; margin-bottom: 8px; }
# .hero p { color: #374151; }
#
# /* Login card (centered) */
# .login-card {
#   max-width: 420px;
#   margin: 0 auto;
#   background: var(--card-bg);
#   padding: 18px;
#   border-radius: 12px;
#   border: 1px solid #eef2f7;
#   box-shadow: 0 4px 18px rgba(15,23,42,0.04);
# }
# .login-card h3 { margin-bottom: 12px; }
# .form-row { margin-bottom: 12px; }
# label { display:block; font-weight:600; margin-bottom:6px; color: #111827; }
# input[type="text"], input[type="password"] {
#   width: 100%;
#   padding: 10px 12px;
#   border-radius: 8px;
#   border: 1px solid #d1d9e6;
#   font-size: 0.95rem;
# }
# .error { color: #b91c1c; font-size: 0.9rem; margin-top: 6px; }
#
# /* Buttons */
# .btn {
#   display:inline-block;
#   padding: 10px 14px;
#   border-radius: 10px;
#   border: none;
#   background: var(--accent);
#   color: #fff;
#   font-weight: 700;
#   cursor: pointer;
# }
# .btn:active { transform: translateY(1px); }
#
# /* Footer */
# .site-footer {
#   background: var(--footer-bg);
#   padding: 14px 0;
#   text-align: center;
#   margin-top: 36px;
#   color: #374151;
#   font-size: 0.95rem;
#   border-top: 1px solid #e6eef9;
# }
#
# /* Responsive adjustments */
# @media (max-width: 760px) {
#   .site-header .wrap { flex-direction: column; align-items: flex-start; gap: 12px; }
#   .hamburger { display: block; }
#
#   /* Initially hide nav on small screens; JS will toggle inline style display */
#   .site-nav { width: 100%; display: none; }
#   .site-nav ul { flex-direction: column; gap: 8px; padding-top: 8px; }
#   .site-nav a { background: none; color: var(--accent-dark); padding: 10px 8px; }
# }
