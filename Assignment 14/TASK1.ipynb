# %% [raw]
# from IPython.display import HTML, display
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Student Info Portal</title>
#
#     <!-- External CSS (Task 2) -->
#     <link rel="stylesheet" href="styles.css">
#
#     <!-- Inline colorful base styling (Task 1) -->
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background: #f7f9fc;
#         }
#
#         header {
#             background: #4c8bf5;
#             color: white;
#             padding: 20px;
#             text-align: center;
#             font-size: 28px;
#             font-weight: bold;
#         }
#
#         nav {
#             background: #e8effd;
#             padding: 12px;
#         }
#
#         nav ul {
#             list-style: none;
#             margin: 0;
#             padding: 0;
#             display: flex;
#             gap: 20px;
#         }
#
#         nav a {
#             text-decoration: none;
#             color: #1f4fb2;
#             font-weight: bold;
#             font-size: 18px;
#         }
#
#         nav a:hover {
#             color: #0d2f73;
#             text-decoration: underline;
#         }
#
#         main {
#             padding: 30px;
#             text-align: center;
#         }
#
#         main h2 {
#             font-size: 26px;
#             color: #333;
#         }
#
#         footer {
#             background: #dfe6f3;
#             text-align: center;
#             padding: 12px;
#             margin-top: 40px;
#             color: #333;
#             font-size: 14px;
#         }
#     </style>
# </head>
# <body>
#
#     <!-- Header -->
#     <header>
#         Student Info Portal
#     </header>
#
#     <!-- Navigation -->
#     <nav>
#         <ul>
#             <li><a href="#">Home</a></li>
#             <li><a href="#">Students</a></li>
#             <li><a href="#">About</a></li>
#             <li><a href="#">Contact</a></li>
#         </ul>
#     </nav>
#
#     <!-- Main Section -->
#     <main>
#         <h2>Welcome</h2>
#         <p>This portal helps manage student information and quick lookups.</p>
#
#         <!-- Login Form (Task 3) -->
#         <div class="login-card">
#             <h3>Login</h3>
#             <form id="loginForm" method="POST" action="/login" novalidate>
#
#                 <div class="form-row">
#                     <label for="username">Username</label>
#                     <input id="username" name="username" type="text" autocomplete="username" />
#                     <div id="userError" class="error" aria-live="polite"></div>
#                 </div>
#
#                 <div class="form-row">
#                     <label for="password">Password</label>
#                     <input id="password" name="password" type="password" autocomplete="current-password" />
#                     <div id="passError" class="error" aria-live="polite"></div>
#                 </div>
#
#                 <button type="submit" class="btn">Login</button>
#             </form>
#         </div>
#     </main>
#
#     <!-- Footer -->
#     <footer>
#         © 2025 Student Info Portal — Built for Lab 14
#     </footer>
#
#     <!-- JavaScript for form validation (Task 3) -->
#     <script src="login.js"></script>
#
# </body>
# </html>
