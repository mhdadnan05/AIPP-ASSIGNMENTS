# %% [markdown]
# **Description:** Write python program for sample_student class with attributes like name, roll no., hostel_status and fee_update method and display_details method. Write comments manually for each line/code block. Ask an AI tool to add inline comments explaining each line/step. Compare the AI-generated comments with your manually written one.
#
# **Expected Output:** Critically analyze AI-generated code comments.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** document the Sample_student class and its functions (__init__(), fee_update(), and display_details()) using doc strings and inline comments to explain each step

# %% [markdown]
# **Code:**

# %%
class Sample_student:
  """
  This is a class that manages an individual student data
  """
  def __init__(self,name,roll_no,hostel_status):
    """
    This function initializes the student details

    Args:
    name: Name of the student
    roll_no: Roll number of the student
    hostel_status: Hostel status of student
    fee_paid: Fee paid by student

    Returns: None
    """
    self.name = name
    self.roll_no = roll_no
    self.hostel_status = hostel_status
    self.fee_paid = 0

  def fee_update(self, fee):
    """
    This function updates the fee of a student

    Args:
    fee: Fee paid by student

    Returns:
    True: If the fee update was successful
    False: If the fee update was not successful
    """
    if type(fee) == type(int()) and fee > 0:
      self.fee_paid += fee
      return True
    else:
      print("Invalid input")
      return False

  def display_details(self):
    """
    This function displays the student details

    Args: None
    Returns: None
    """
    print(f"name: {self.name}, rollno.: {self.roll_no}, hostel status: {self.hostel_status}, total fee paid: {self.fee_paid}")

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
class Sample_student:
  """
  Represents a sample student with attributes like name, roll number, hostel status, and fee payment.
  """

  def __init__(self,name,roll_no,hostel_status):
    """
    Initializes a new Sample_student object.

    Args:
      name (str): The name of the student.
      roll_no (str): The roll number of the student.
      hostel_status (bool): True if the student resides in a hostel, False otherwise.
    """
    self.name = name  # Assign the provided name to the student object
    self.roll_no = roll_no  # Assign the provided roll number
    self.hostel_status = hostel_status  # Assign the hostel status
    self.fee_paid = 0  # Initialize the fee paid to 0

  def fee_update(self, fee):
    """
    Updates the fee paid by the student.

    Args:
      fee (int): The amount of fee to be added.

    Returns:
      bool: True if the fee update is successful, False otherwise.
    """
    # Check if the fee is a positive integer
    if type(fee) == type(int()) and fee > 0:
      self.fee_paid += fee  # Add the fee to the total fee paid
      return True  # Indicate successful update
    else:
      print("Invalid input")  # Print an error message for invalid input
      return False  # Indicate unsuccessful update

  def display_details(self):
    """
    Displays the details of the student including name, roll number, hostel status, and total fee paid.
    """
    print(f"name: {self.name}, rollno.: {self.roll_no}, hostel status: {self.hostel_status}, total fee paid: {self.fee_paid}")

# %% [markdown]
# **Observations:** The documentation of code generated by AI follows a proper standard i.e. consistent and is easier to understand.
